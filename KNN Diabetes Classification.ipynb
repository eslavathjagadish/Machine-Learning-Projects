# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Asus\\Downloads'

# %%
#Laoding the dataset
dia_data=pd.read_csv('C:/Users/Asus/Downloads/Data/diabetes.csv')

# %%
#Checking or Studing the dataset with assigned vairable
dia_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#Stastical Analysis
dia_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Descriptive statistic details about the data (NOTE:-only numerical columns would be displayed here unless parameter include="all")

dia_data.describe()

#Count indicates no.of Non Empty rows in feature.
#Mean indicates mean value of that feature.
#std(Standard Deviation) indicates std value of that feature.
#Min indicates minimum value of that feature.
#25%,50%,75% indicates quartile of each feature(this helps in detection of Outliers in the data).
#Max indicates maximum value of feature.
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#from Horizontal perspective of features  
dia_data.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
#It is better to replace zeros with nan since after that counting them would be easier and zeros need to be replaced 
#with suitable values.
dia_data_proxy=dia_data.copy(deep=True)
dia_data_proxy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]=dia_data_proxy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
#Displaying count of NaN in data
dia_data_proxy.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
#Visualization or skewnessof features with NaN values
p=dia_data.hist(figsize=(28,28))

# %%
#Imputing NaN values in columns with there distribution 
dia_data_proxy['Glucose'].fillna(dia_data_proxy['Glucose'].mean(),inplace=True)
dia_data_proxy['BloodPressure'].fillna(dia_data_proxy['BloodPressure'].mean(),inplace=True)
dia_data_proxy['SkinThickness'].fillna(dia_data_proxy['SkinThickness'].median(),inplace=True)
dia_data_proxy['Insulin'].fillna(dia_data_proxy['Insulin'].median(),inplace=True)
dia_data_proxy['BMI'].fillna(dia_data_proxy['BMI'].median(),inplace=True)
dia_data_proxy['Pregnancies'].fillna(dia_data_proxy['Pregnancies'].median(),inplace=True)

# %%
#Skewness after NaN imputing NaN values
p=dia_data_proxy.hist(figsize=(28,28))

# %%
dia_data.shape
# Out:
# (768, 9)

# %%
dia_data_proxy.shape
# Out:
# (768, 9)

# %%
#Scatter matrix of uncleaned data
from pandas.plotting import scatter_matrix
p=scatter_matrix(dia_data,figsize=(28,28))

# %%
#Plotting of Clean Data with Positive and Negative skewness of features
p=sns.pairplot(dia_data_proxy,hue='Outcome')

# %% [markdown]
# #Pearson's Correlation Coefficient to help in finding out the relationship between two quantities.

# %%
#Heat map of Unclean data
plt.figure(figsize=(12,10))
p=sns.heatmap(dia_data.corr(),annot=True,cmap='RdYlGn')

# %%
#heatmap of Clean Data (Note: VERY SLIGHT CHANGES MIGHT BE OBSERVED ON THE FEATURES)
plt.figure(figsize=(12,10))
p=sns.heatmap(dia_data_proxy.corr(),annot=True,cmap='RdYlGn')

# %% [markdown]
# SCALING THE DATA

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
X=pd.DataFrame(sc_X.fit_transform(dia_data_proxy.drop(['Outcome'],axis=1),),columns=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPredigreeFunction','Age'])
X
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.865108      -0.033518       0.670643 -0.181541  0.166619
# 1      -0.844885 -1.206162      -0.529859      -0.012301 -0.181541 -0.852200
# 2       1.233880  2.015813      -0.695306      -0.012301 -0.181541 -1.332500
# 3      -0.844885 -1.074652      -0.529859      -0.695245 -0.540642 -0.633881
# 4      -1.141852  0.503458      -2.680669       0.670643  0.316566  1.549303
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.680125       0.297376       2.150354  0.455573  0.064737
# 764    -0.547919  0.010298      -0.198965      -0.239949 -0.181541  0.632365
# 765     0.342981 -0.022579      -0.033518      -0.695245 -0.332132 -0.910418
# 766    -0.844885  0.141808      -1.026200      -0.012301 -0.181541 -0.342790
# 767    -0.844885 -0.943143      -0.198965       0.215347 -0.181541 -0.299127
#
#      DiabetesPredigreeFunction       Age
# ...

# %%
#Just to Correlate with the RAW data for the modifications we made till now
dia_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = dia_data.drop("Outcome",axis = 1)
y=dia_data_proxy.Outcome

# %% [markdown]
# SPLITTING THE DATA

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=1/3,random_state=123,stratify=y)
from sklearn.neighbors import KNeighborsClassifier

# %%
test_scores=[]
train_scores=[]

# %%
for i in range(1,15):
    knn=KNeighborsClassifier(i)
    knn.fit(X_train,y_train)
    train_scores.append(knn.score(X_train,y_train))
    test_scores.append(knn.score(X_test,y_test))

# %%
# score that comes from testing on the same datapoints that were used for training
max_train_score=max(train_scores)
train_scores_ind=[i for i,v in enumerate(train_scores) if v==max_train_score]
print('MAX train score {} % and k={}'.format(max_train_score*100,list(map(lambda x:x+1, train_scores_ind))))
# Out:
# MAX train score 100.0 % and k=[1]

# %%
# score that comes from testing on the same datapoints that were used for testing
max_test_score=max(test_scores)
test_scores_ind=[i for i,v in enumerate(test_scores) if v==max_test_score]
print('MAX test score {} % and k={}'.format(max_test_score*100,list(map(lambda x:x+1, test_scores_ind))))
# Out:
# MAX test score 76.171875 % and k=[14]

# %% [markdown]
# VISUALIZING REPORT

# %%
plt.figure(figsize=(12,5))
p=sns.lineplot(range(1,15),train_scores,marker='X',label='Train Score')
p=sns.lineplot(range(1,15),test_scores,marker='o',label='Test Score')

# %% [markdown]
# As per The best result is captured at k = 14 hence 14 is used for the final model

# %%
#Setup a knn classifier with k neighbors
knn=KNeighborsClassifier(14)
knn.fit(X_train,y_train)
knn.score(X_test,y_test)
# Out:
# 0.76171875

# %%
value = 20000
width = 20000
plot_decision_regions(X.values, y.values, clf=knn, legend=2, 
                      filler_feature_values={2: value, 3: value, 4: value, 5: value, 6: value, 7: value},
                      filler_feature_ranges={2: width, 3: width, 4: width, 5: width, 6: width, 7: width},
                      X_highlight=X_test.values)

# Adding axes annotations
plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.title('KNN with Diabetes Data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-74026bc600d0> in <module>
#       1 value = 20000
#       2 width = 20000
# ----> 3 plot_decision_regions(X.values, y.values, clf=knn, legend=2,
#       4                       filler_feature_values={2: value, 3: value, 4: value, 5: value, 6: value, 7: value},
#       5                       filler_feature_ranges={2: width, 3: width, 4: width, 5: width, 6: width, 7: width},
#
# NameError: name 'plot_decision_regions' is not defined

# %% [markdown]
# MODEL PERFORMANCE ANALYSIS

# %%
from sklearn.metrics import confusion_matrix
y_pred=knn.predict(X_test)
confusion_matrix(y_test,y_pred)
pd.crosstab(y_test,y_pred,rownames=['True'],colnames=['Predicted'],margins=True)
# Out:
# Predicted    0   1  All
# True
# 0          146  21  167
# 1           40  49   89
# All        186  70  256

# %% [markdown]
# PLOTTING PREDICITON WITH CONFUSION MATRIX

# %%
y_pred=knn.predict(X_test)
from sklearn import metrics
cnf_matrix=metrics.confusion_matrix(y_test,y_pred)
p=sns.heatmap(pd.DataFrame(cnf_matrix),annot=True,cmap='YlGnBu',fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('confusion matrix')
# Out:
# Text(0.5, 1.0, 'confusion matrix')

# %% [markdown]
# CLASSIFICATION REPORT

# %%
#Importing classification report by using scikit learn
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.83       167
#            1       0.70      0.55      0.62        89
#
#     accuracy                           0.76       256
#    macro avg       0.74      0.71      0.72       256
# weighted avg       0.76      0.76      0.75       256

# %% [markdown]
# CHECKING HOW GOOD MODEL IS WITH ROC AUC CURVE

# %%
from sklearn.metrics import roc_curve

# %%
y_pred_proba=knn.predict_proba(X_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba)

# %%
plt.plot([0,1],[0,1])
plt.plot(fpr,tpr,label='KNN')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('KNN(n_neighbors=14) ROC CURVE')
plt.show()

# %%
#Area under ROC curve
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred_proba)
# Out:
# 0.8073067348449169

# %% [markdown]
# HYPER PARAMETER OPTIMIZATION

# %%
from  sklearn.model_selection import GridSearchCV

# %%
param_grid={'n_neighbors':np.arange(1,50)}
knn=KNeighborsClassifier()
knn_CV=GridSearchCV(knn,param_grid,cv=10)
knn_CV.fit(X,y)
print('Best Score:'+str(knn_CV.best_score_))
print('Best Parameters:'+str(knn_CV.best_params_))
# Out:
# Best Score:0.7552973342447027
# Best Parameters:{'n_neighbors': 17}

# %% [markdown]
# HERE WE CONCLUDE THAT MODEL'S
# BEST ACCURACY IS: 80.73%
# &
# BEST KNN NEIGHBOR PARAMETER IS: 17
